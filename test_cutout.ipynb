# %%
from src.misc import *
from src.SPECTRUM import Spectrum
from src.FITSPECTRUM import FitSpectrum
from src.DP import DP
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table
import pandas as pd
import io
import astropy.io.fits

# %%
import src.downloadCutout as downloadCutout

rect = downloadCutout.Rect.create(
    ra=202.715347,
    dec=-1.778709,
    sw="1arcmin",
    sh="1arcmin",
)

images = downloadCutout.download(rect)

# %%
# Multiple images (of various filters) are returned.
# We look into the first one of them.

metadata, data = images[0]
hdus_g = astropy.io.fits.open(io.BytesIO(data))

metadata, data = images[2]
hdus_r = astropy.io.fits.open(io.BytesIO(data))


metadata, data = images[4]
hdus_z = astropy.io.fits.open(io.BytesIO(data))

# %%
r, g, b = hdus_z[1].data, hdus_r[1].data, hdus_g[1].data
plt.imshow(np.dstack([r, g, b]), origin="lower")
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.4898744..321.00406].
