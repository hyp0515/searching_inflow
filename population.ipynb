# %%
from astropy.io import fits
from src.misc import *
from src.SPECTRUM import Spectrum
from src.FITSPECTRUM import FitSpectrum
from src.DP import DP
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table
import pandas as pd
plt.rcParams['font.size'] = 16

# %%
DP = DP()
all_df, _, _, _ = DP.extract_fits_data('./catalogs/0428_all_test.fits')
dps_df, _, _, _ = DP.extract_fits_data('./catalogs/0428_dps_test.fits')

# %%
dps_df.columns
# Out:
# Index(['TARGETID', 'RA', 'DEC', 'Z', 'LOGM', 'LOGSFR', 'DV_R', 'DV_L',
#        'SIGMA_R', 'SIGMA_L', 'SIGMA_1COMP', 'P_VALUE', 'OII3726_FLUX_1COMP',
#        'OII3729_FLUX_1COMP', 'Hbeta_FLUX_1COMP', 'OIII4959_FLUX_1COMP',
#        'OIII5007_FLUX_1COMP', 'NII6548_FLUX_1COMP', 'Halpha_FLUX_1COMP',
#        'NII6583_FLUX_1COMP', 'SII6716_FLUX_1COMP', 'SII6731_FLUX_1COMP',
#        'OII3726_FLUX_2COMP_L', 'OII3729_FLUX_2COMP_L', 'Hbeta_FLUX_2COMP_L',
#        'OIII4959_FLUX_2COMP_L', 'OIII5007_FLUX_2COMP_L',
#        'NII6548_FLUX_2COMP_L', 'Halpha_FLUX_2COMP_L', 'NII6583_FLUX_2COMP_L',
#        'SII6716_FLUX_2COMP_L', 'SII6731_FLUX_2COMP_L', 'OII3726_FLUX_2COMP_R',
#        'OII3729_FLUX_2COMP_R', 'Hbeta_FLUX_2COMP_R', 'OIII4959_FLUX_2COMP_R',
#        'OIII5007_FLUX_2COMP_R', 'NII6548_FLUX_2COMP_R', 'Halpha_FLUX_2COMP_R',
#        'NII6583_FLUX_2COMP_R', 'SII6716_FLUX_2COMP_R', 'SII6731_FLUX_2COMP_R',
#        'OII3726_DP', 'OII3729_DP', 'Hbeta_DP', 'OIII4959_DP', 'OIII5007_DP',
# ...

# %%
all_df.columns
# Out:
# Index(['TARGETID', 'RA', 'DEC', 'Z', 'LOGM', 'LOGSFR', 'DV_R', 'DV_L',
#        'SIGMA_R', 'SIGMA_L', 'SIGMA_1COMP', 'P_VALUE', 'OII3726_FLUX_1COMP',
#        'OII3729_FLUX_1COMP', 'Hbeta_FLUX_1COMP', 'OIII4959_FLUX_1COMP',
#        'OIII5007_FLUX_1COMP', 'NII6548_FLUX_1COMP', 'Halpha_FLUX_1COMP',
#        'NII6583_FLUX_1COMP', 'SII6716_FLUX_1COMP', 'SII6731_FLUX_1COMP',
#        'OII3726_FLUX_2COMP_L', 'OII3729_FLUX_2COMP_L', 'Hbeta_FLUX_2COMP_L',
#        'OIII4959_FLUX_2COMP_L', 'OIII5007_FLUX_2COMP_L',
#        'NII6548_FLUX_2COMP_L', 'Halpha_FLUX_2COMP_L', 'NII6583_FLUX_2COMP_L',
#        'SII6716_FLUX_2COMP_L', 'SII6731_FLUX_2COMP_L', 'OII3726_FLUX_2COMP_R',
#        'OII3729_FLUX_2COMP_R', 'Hbeta_FLUX_2COMP_R', 'OIII4959_FLUX_2COMP_R',
#        'OIII5007_FLUX_2COMP_R', 'NII6548_FLUX_2COMP_R', 'Halpha_FLUX_2COMP_R',
#        'NII6583_FLUX_2COMP_R', 'SII6716_FLUX_2COMP_R', 'SII6731_FLUX_2COMP_R',
#        'OII3726_DP', 'OII3729_DP', 'Hbeta_DP', 'OIII4959_DP', 'OIII5007_DP',
# ...

# %%
plt.hist(dps_df['Z'], bins=30)
print(dps_df['Z'].median())
plt.show()
# Out:
# 0.19584551453590393

# %%
plt.figure(figsize=(8,6))
plt.hist(dps_df['DV_R']-dps_df['DV_L'], bins=30, color='C1')
plt.axvline(211, color='r', linestyle='--', linewidth=3, label='SDSS separation cut')
plt.axvline(97, color='g', linestyle='--', linewidth=3, label='DESI separation cut')
plt.xlim(left=0)
plt.xlabel('Peak Separation (km/s)')
plt.ylabel('Count')
plt.title('Distribution of Peak Separations')
plt.legend()
plt.tight_layout()
plt.savefig('./figures/progress_apr/peak_separation_distribution.png')
plt.show()

# %%
print(len(dps_df[dps_df['DV_R']-dps_df['DV_L'] > 97])/99812)
print(len(dps_df[dps_df['DV_R']-dps_df['DV_L'] > 211])/99812)
# Out:
# 0.14398068368532843
# 0.021881136536688977

# %%
print(len(dps_df[dps_df['DV_R']-dps_df['DV_L'] > 97]))
# Out:
# 14371

# %%
dps_df.sort_values('SIGMA_R', ascending=False).head(20)
# Out:
#                 TARGETID          RA       DEC         Z       LOGM  \
# 9444   39627776201852370  211.826218 -0.388770  0.177552  10.317112
# 16229  39627805985604065  187.019409  0.815862  0.402560  11.157273
# 17018  39627806434396707  213.866089  0.863446  0.125449  10.989308
# 12942  39627788474390118  223.467911  0.047747  0.068872   9.969708
# 18950  39627817914208211  178.216110  1.163323  0.135217   9.622567
# 3441   39627752143327125  217.919556 -1.451486  0.277360  10.344568
# 13970  39627794249941092  207.502762  0.303788  0.219927  10.641716
# 8509   39627775719508857  183.133682 -0.603044  0.188201  11.041872
# 13487  39627793998284849  192.614258  0.229326  0.046835  10.730901
# 12446  39627788218533694  208.098633  0.062066  0.250538  11.250815
# 17120  39627806484727167  216.793411  0.741766  0.326641  10.589890
# 4706   39627758036322054  209.077072 -1.253912  0.247431   9.521063
# 7906   39627770187224787  213.472824 -0.757543  0.118298  11.161664
# ...

# %%
dps_df.sort_values('SIGMA_L', ascending=False).head(20)
# Out:
#                 TARGETID          RA       DEC         Z       LOGM    LOGSFR  \
# 1472   39627745805731000  200.057358 -1.859886  0.221200  11.028525 -9.125453
# 2320   39627751522568102  180.848053 -1.412246  0.316521  11.136950  1.728777
# 5599   39627763748964880  189.638916 -1.067022  0.187426  10.452728 -5.389623
# 11006  39627782229069554  211.176483 -0.178559  0.356363  10.668675  1.205011
# 5908   39627763920931770  199.878418 -1.054401  0.219227  10.790133  0.576731
# 335    39627739740767347  198.563751 -1.972422  0.246099  10.437529  1.164278
# 19998  39627818446882373  209.807343  1.176532  0.253174  10.410436  0.452856
# 8119   39627770287882739  219.269287 -0.841091  0.216202  10.938835  0.416211
# 7618   39627770032033200  204.140244 -0.660093  0.415810  10.521138  1.863829
# 2398   39627751556126124  182.978806 -1.424618  0.296237   9.589593  1.766945
# 17875  39627812113482588  192.293854  1.014610  0.183624  10.520328  0.703291
# ...
