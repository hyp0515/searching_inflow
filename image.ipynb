# %%
from astropy.io import fits
from src.misc import *
from src.SPECTRUM import Spectrum
from src.FITSPECTRUM import FitSpectrum
from src.DP import DP
import matplotlib.pyplot as plt
import numpy as np
from astropy.table import Table

# %%
DP = DP()
dps_df, _, left_2comp, right_2comp = DP.extract_fits_data('./catalogs/dp_catalog.fits')

# %%
# idx = np.random.choice(SPECTRA.n_spectra, size=1, replace=False)[0]
# id = SPECTRA.targetID[idx]
id = 39627739799486898
id_df = dps_df[dps_df['TARGETID']==id]
print(image_link(id_df['RA'].to_numpy()[0], id_df['DEC'].to_numpy()[0], plot=True, save_image=True, fname=f"./images/{id}_image.jpg"))
print(spectrum_link(id))
# Out:
# Saved ./images/39627739799486898_image.jpg
# https://www.legacysurvey.org/viewer?ra=202.01919555664062&dec=-1.8901294469833374&layer=hsc-dr3&zoom=14
# https://www.legacysurvey.org/viewer/desi-spectrum/dr1/targetid39627739799486898
